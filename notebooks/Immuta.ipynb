# %%
import pyodbc
import pandas as pd
conn = pyodbc.connect('DSN=immuta_data_user')

# %%
sql = '''SELECT * FROM public.credit_transactions limit 100'''
df = pd.read_sql(sql,conn)
df.head(10)
# Out:
#    transaction_id                                         first_name  \
# 0         3456790  3c791706ca5fe74ca89f6c5a9279a7f48e3f103537e25d...
# 1         3457087  5c819d4f52a6a342e9c8af067d92ae9dec240d30cd3bdb...
# 2         3457683  5960a1a5bf0be3b3591beedddfca27f2d0f7d1a5c5066c...
# 3         3456791  a58988cf09c5e867eb85cf7234a508e0f4fc970a758aa6...
# 4         3456792  ce6e9f2dd3a2d482886b2719f4f6a7ca5afee6a11f4218...
# 5         3456793  75bb976fc22c4044603394df36ded7bddc9aa4feb3a63a...
# 6         3456794  3442ead238a54e75ccac30356269959515179730cfc9f1...
# 7         3456795  e719578c5b0dabbdd5b2d0a8c5f500e42dd3af998d31ca...
# 8         3456796  bf773c5f06a1b671bb55eafeb86f216061983ca1d0373d...
# 9         3456797  ad3edf7240ce54d46cd57d87a31271a9061abcee1cea9f...
#
#                                            last_name  \
# 0  a8842394394a7173f7052f44ef297e46c0debe76268f0c...
# 1  bd8009453d5e0cf50d55b3cc5db766245fec084d448298...
# ...
